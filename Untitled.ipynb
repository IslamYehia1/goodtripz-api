# %%
import pandas as pd

# %%
df = pd.read_csv("./airports.csv")
df.dropna(subset="iata_code" , inplace=True);
df.to_csv("modifiedAirports")
df2 = pd.read_csv("./modifiedAirports.csv")
df2
# Out:
#           id            type                                    name  \
# 0       4650   small_airport                          Utirik Airport
# 1       6924   small_airport                 Ocean Reef Club Airport
# 2       7063   small_airport                   Pilot Station Airport
# 3       7139   small_airport                   Crested Butte Airpark
# 4       7545   small_airport                       LBJ Ranch Airport
# ...      ...             ...                                     ...
# 9237   27243   large_airport  Shenyang Taoxian International Airport
# 9238  342103          closed                       Mt Logan Airstrip
# 9239   27244  medium_airport             Yanji Chaoyangchuan Airport
# 9240  317861  medium_airport                   Yingkou Lanqi Airport
# 9241  342102          closed                  Scandium City Heliport
#
#       latitude_deg  longitude_deg  elevation_ft iso_country  \
# 0        11.222000     169.852005           4.0          MH
# ...

# %%
idx = df2["name"].apply(len).idxmax()
idx
# Out:
# 2670

# %%
len(df.iloc[idx, :]["name"])
# Out:
# 79

# %%
df2
# Out:
#           id            type                                    name  \
# 0       4650   small_airport                          Utirik Airport
# 1       6924   small_airport                 Ocean Reef Club Airport
# 2       7063   small_airport                   Pilot Station Airport
# 3       7139   small_airport                   Crested Butte Airpark
# 4       7545   small_airport                       LBJ Ranch Airport
# ...      ...             ...                                     ...
# 9237   27243   large_airport  Shenyang Taoxian International Airport
# 9238  342103          closed                       Mt Logan Airstrip
# 9239   27244  medium_airport             Yanji Chaoyangchuan Airport
# 9240  317861  medium_airport                   Yingkou Lanqi Airport
# 9241  342102          closed                  Scandium City Heliport
#
#       latitude_deg  longitude_deg  elevation_ft iso_country  \
# 0        11.222000     169.852005           4.0          MH
# ...
